# %%
val=10
val
# Out:
# 10

# %%
name= "manyam Jagadeeswar"
name
type(name)
# Out:
# str

# %%
val="Jagadeeswar"
type(val)
# Out:
# str

# %%
name = "Jagadeeswar"
age = 22
salary = 55000.50
is_active = True
print(f"name:{name},age: {age}, salary:{salary} and is_active:{is_active}")
# Out:
# name:Jagadeeswar,age: 22, salary:55000.5 and is_active:True

# %%
a = 10
b = 20
print(f"Before Swaping :{a}, {b} ")
a, b = b, a
print(f"After Swaping :{a}, {b} ")
# Out:
# Before Swaping :10, 20
# After Swaping :20, 10

# %%
x, y, z = 10, 20, 30
list=[]
list.append(x)
list.append(y)
list.append(z)
list
# Out:
# [10, 20, 30]

# %%
list=[]
list.extend([x,y,z]) #extend() is the appropriate method because you're adding multiple elements.
list
# Out:
# [10, 20, 30]

# %%
host, port = "localhost", 5432
print(host)
print(type(host))
print(port)
print(type(port))
# Out:
# localhost
# <class 'str'>
# 5432
# <class 'int'>
